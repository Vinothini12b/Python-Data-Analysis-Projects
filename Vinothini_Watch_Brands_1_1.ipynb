# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinothini12b/Python-Data-Analysis-Projects/blob/main/Vinothini_Watch_Brands_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WatchBrands 1.1

# %% [markdown]
# ## ***`Task 1: Import the pandas library and create a blank dataframe.`***

# %%
import pandas as pd
data=pd.DataFrame()
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# `***## Task 2: Add a column named 'Brands' to the table with the below Watch Brand names, and then print the table.***`

# %%
data["Brands"]=["Boat","fastrack","Titan","Sonata","Rolex","Fossil"]
data
# Out:
#      Brands
# 0      Boat
# 1  fastrack
# 2     Titan
# 3    Sonata
# 4     Rolex
# 5    Fossil

# %% [markdown]
# `***## Task 3: In the above table add one more column named “WatchesPurchased”.Print this table ***`

# %%
data["WatchesPurchased"]=[200,300,100,150,50,200]
data
# Out:
#      Brands  WatchesPurchased
# 0      Boat               200
# 1  fastrack               300
# 2     Titan               100
# 3    Sonata               150
# 4     Rolex                50
# 5    Fossil               200

# %% [markdown]
# # WatchBrands 1.2

# %% [markdown]
# ***`Task 1: In the above table add a column named “WatchesSold” to the table with the below “WatchesSold” numbers against every brand, and then print the table.
# `***

# %%
data["WatchesSold"]=[150,210,80,100,20,160]
data
# Out:
#      Brands  WatchesPurchased  WatchesSold
# 0      Boat               200          150
# 1  fastrack               300          210
# 2     Titan               100           80
# 3    Sonata               150          100
# 4     Rolex                50           20
# 5    Fossil               200          160

# %% [markdown]
# **`Task 2: Add a column named “WatchesUnsold” to the table. WatchesUnsold are calculated by the formula (WatchesPurchased-WatchedSold), and then print the table.
# `**

# %%
data["WatchesUnsold"]=data["WatchesPurchased"]-data["WatchesSold"]
data
# Out:
#      Brands  WatchesPurchased  WatchesSold  WatchesUnsold
# 0      Boat               200          150             50
# 1  fastrack               300          210             90
# 2     Titan               100           80             20
# 3    Sonata               150          100             50
# 4     Rolex                50           20             30
# 5    Fossil               200          160             40

# %% [markdown]
# ***`Task 3: Add a column named“UnsoldPercent” to the table by calculating “UnsoldPercent”  and then print the table.
#
# Where, “UnsoldPercent” = WatchesUnsold / WatchesPurchased * 100`***

# %%
data["UnsoldPercent"]=data["WatchesUnsold"] / data["WatchesPurchased"] * 100
data
# Out:
#      Brands  WatchesPurchased  WatchesSold  WatchesUnsold  UnsoldPercent
# 0      Boat               200          150             50      25.000000
# 1  fastrack               300          210             90      30.000000
# 2     Titan               100           80             20      20.000000
# 3    Sonata               150          100             50      33.333333
# 4     Rolex                50           20             30      60.000000
# 5    Fossil               200          160             40      20.000000

# %% [markdown]
# WatchBrands_1.3

# %% [markdown]
# ***`Task 1: Find the sum of total purchases made from all brands.`***

# %%
data["WatchesPurchased"].sum()
# Out:
# 1000

# %% [markdown]
# ***`Task 2: Find the minimum number of purchases made among all the brands.`***

# %%
data["WatchesPurchased"].min()
# Out:
# 50

# %% [markdown]
# ***`Task 3: Find the average number of purchases made among all the brands.`***

# %%
data["WatchesPurchased"].mean()
# Out:
# 166.66666666666666

# %% [markdown]
# ***`Task 4: Find the total number of brands.`***

# %%
data["Brands"].count()
# Out:
# 6

# %% [markdown]
# ***`Task 5: Find the average of total watches sold by all the brands.`***

# %%
int(data["WatchesSold"].mean())
# Out:
# 120

# %% [markdown]
# ***`Task 6: Find the maximum number of watches unsold among all the brands.`***

# %%
data["WatchesUnsold"].max()
# Out:
# 90

# %% [markdown]
# ***`Task 7: Find the average of “UnsoldPercent” among all the brands.`***

# %%
data["UnsoldPercent"].mean()
# Out:
# 31.388888888888886
